# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
series = pd.read_csv('monthly robbery.csv', header = 0, index_col = 0, parse_dates = True, squeeze = True)
series.head()
# Out:
# Month
# 1966-01-01    41
# 1966-02-01    39
# 1966-03-01    50
# 1966-04-01    40
# 1966-05-01    43
# Name: Robberies, dtype: int64

# %%
series.describe()
# Out:
# count    118.000000
# mean     196.288136
# std      128.043602
# min       29.000000
# 25%       85.500000
# 50%      166.000000
# 75%      296.750000
# max      500.000000
# Name: Robberies, dtype: float64

# %%
series.plot()
plt.show()
