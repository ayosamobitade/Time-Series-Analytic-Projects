# %% [markdown]
# ## Daily Minimum Temperature

# %%
# importing necessaty libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading the dataset
dataset = pd.read_csv('daily-minimum-temperatures.csv')
dataset.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
# loading and creating the series

series = pd.read_csv('daily-minimum-temperatures.csv', header = 0, index_col = 0, parse_dates=True, squeeze = True)
series
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
#               ...
# 1990-12-27    14.0
# 1990-12-28    13.6
# 1990-12-29    13.5
# 1990-12-30    15.7
# 1990-12-31    13.0
# Name: Temp, Length: 3650, dtype: float64

# %%
# checking for the number of observation

print(series.size)
# Out:
# 3650

# %%
# creating lag features

temperatures = pd.DataFrame(series.values)

dataframe = pd.concat([temperatures.shift(3), temperatures.shift(2), temperatures.shift(1), temperatures], axis = 1)
dataframe.columns = ['t-2', 't-1', 't', 't+1']
dataframe.head(7)
# Out:
#     t-2   t-1     t   t+1
# 0   NaN   NaN   NaN  20.7
# 1   NaN   NaN  20.7  17.9
# 2   NaN  20.7  17.9  18.8
# 3  20.7  17.9  18.8  14.6
# 4  17.9  18.8  14.6  15.8
# 5  18.8  14.6  15.8  15.8
# 6  14.6  15.8  15.8  15.8

# %%
# adding summaries of values

temps = pd.DataFrame(series.values)

shifted = temps.shift(1)
window = shifted.rolling(window=2)
mean = window.mean()

dataframe = pd.concat([mean, temps], axis=1)
dataframe.columns = ['mean(t-1, t)', 't+1']
print(dataframe.head(7))
# Out:
#    mean(t-1, t)   t+1
# 0           NaN  20.7
# 1           NaN  17.9
# 2         19.30  18.8
# 3         18.35  14.6
# 4         16.70  15.8
# 5         15.20  15.8
# 6         15.80  15.8

# %%
# expanding with statistics adding the min, mean, max
temps = pd.DataFrame(series.values)

shifted = temps.shift(1)
window = temps.expanding()


dataframe = pd.concat([window.min(), window.mean(), window.max(), temps.shift(-1)], axis=1)
dataframe.columns = ['min', 'mean', 'max', 't+1']
print(dataframe.head(7))
# Out:
#     min       mean   max   t+1
# 0  20.7  20.700000  20.7  17.9
# 1  17.9  19.300000  20.7  18.8
# 2  17.9  19.133333  20.7  14.6
# 3  14.6  18.000000  20.7  15.8
# 4  14.6  17.560000  20.7  15.8
# 5  14.6  17.266667  20.7  15.8
# 6  14.6  17.057143  20.7  17.4

# %%
# some visualizations

#Line plot of the series

series.plot()
plt.show()

# %%
# creating a dot plot

series.plot(style = 'k.')
plt.show()

# %%
# creating a dashline plot

series.plot(style = 'k--')
plt.show()

# %%
# creating stacked line plots

groups = series.groupby(pd.Grouper(freq='A'))
years = pd.DataFrame()
for name, group in groups:
    years[name.year] = group.values
    
years.plot(subplots=True, legend=False)
plt.show()

# %%
# ploting the histogram of the series

series.hist()
plt.show()

# %%
# creating a density plot

series.plot(kind = 'kde')
plt.show()

# %%
# create Boxplot for the series

groups = series.groupby(pd.Grouper(freq='A'))
years = pd.DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.boxplot()
plt.show()

# %%
# create a boxplot of monthly data for 1990

one_year = series['1990']
groups = one_year.groupby(pd.Grouper(freq = 'M'))
months = pd.concat([pd.DataFrame(x[1].values) for x in groups], axis=1)
months = pd.DataFrame(months)
months.columns = range(1,13)
months.boxplot()
plt.show()

# %%
series
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
#               ...
# 1990-12-27    14.0
# 1990-12-28    13.6
# 1990-12-29    13.5
# 1990-12-30    15.7
# 1990-12-31    13.0
# Name: Temp, Length: 3650, dtype: float64

# %%
# create a heat map for year data of the series

groups = series.groupby(pd.Grouper(freq = 'A'))
years = pd.DataFrame()
for name, group in groups:
    years[name.year] = group.values
years = years.T
plt.matshow(years, interpolation = None, aspect = 'auto')
plt.show()

# %%
# heatmap for monthly data of the series

one_year = series['1990']
groups = one_year.groupby(pd.Grouper(freq = 'M'))
months = pd.concat([pd.DataFrame(x[1].values) for x in groups], axis=1)
months = pd.DataFrame(months)
months.columns = range(1,13)
plt.matshow(months, interpolation=None, aspect='auto')
plt.show()

# %%
# lag scale plot

pd.plotting.lag_plot(series)
plt.show()

# %%
# scatter plot of observation for each value in the previous seven day

values = pd.DataFrame(series.values)
lags = 7
columns = [values]
for i in range(1,(lags + 1)):
    columns.append(values.shift(i))
dataframe = pd.concat(columns, axis=1)
columns = ['t']
for i in range(1,(lags + 1)):
    columns.append('t-' + str(i))
dataframe.columns = columns
plt.figure(1)
for i in range(1,(lags + 1)):
    ax = plt.subplot(240 + i)
    ax.set_title('t vs t-' + str(i))
    plt.scatter(x=dataframe['t'].values, y=dataframe['t-'+str(i)].values)
plt.show()

# %%
# creating the autocorrelation plot

pd.plotting.autocorrelation_plot(series)
plt.show()
